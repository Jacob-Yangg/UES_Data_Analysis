# %%
import pandas as pd
workshop = pd.read_csv('/Users/jacobyang/Downloads/WIB x UES Case Study Night.csv')
workshop
# Out:
#                               Meeting ID                             Topic  \
# 0                            98214919825  WIB x UES Case Study Competition
# 1                   Name (Original Name)                        User Email
# 2    WIB and UES | Lillian Wei (she/her)                    l5wei@ucsd.edu
# 3    WIB and UES | Lillian Wei (she/her)                    l5wei@ucsd.edu
# 4    WIB and UES | Lillian Wei (she/her)                    l5wei@ucsd.edu
# ..                                   ...                               ...
# 342                          Disha Birla                   dbirla@ucsd.edu
# 343                    UES (Disha Birla)                   dbirla@ucsd.edu
# 344            WIB-Vienna Tran (she/her)                   v5tran@ucsd.edu
# 345  WIB and UES | Lillian Wei (she/her)                    l5wei@ucsd.edu
# 346  WIB and UES | Lillian Wei (she/her)                    l5wei@ucsd.edu
#
#                  Start Time                End Time          User Email  \
# 0    03/02/2022 07:28:42 PM  03/02/2022 10:12:16 PM      l5wei@ucsd.edu
# 1                 Join Time              Leave Time  Duration (Minutes)
# 2    03/02/2022 08:48:59 PM  03/02/2022 08:49:16 PM                   1
# 3    03/02/2022 08:49:16 PM  03/02/2022 08:49:33 PM                   1
# 4    03/02/2022 08:50:26 PM  03/02/2022 09:03:15 PM                  13
# ..                      ...                     ...                 ...
# 342  03/02/2022 07:30:38 PM  03/02/2022 07:30:42 PM                   1
# 343  03/02/2022 07:30:42 PM  03/02/2022 08:55:06 PM                  85
# 344  03/02/2022 08:41:51 PM  03/02/2022 09:02:09 PM                  21
# 345  03/02/2022 08:46:11 PM  03/02/2022 08:47:00 PM                   1
# 346  03/02/2022 08:48:04 PM  03/02/2022 08:48:34 PM                   1
#
#     Duration (Minutes)     Participants  Unnamed: 7
# 0                  164               68         NaN
# 1                Guest  In Waiting Room         NaN
# 2                   No               No         NaN
# 3                   No               No         NaN
# 4                   No               No         NaN
# ..                 ...              ...         ...
# 342                 No              Yes         NaN
# 343                 No               No         NaN
# 344                 No               No         NaN
# 345                 No               No         NaN
# 346                 No               No         NaN
#
# [347 rows x 8 columns]

# %%
workshop = workshop.get(['Meeting ID', 'Topic', 'User Email'])
workshop.rename(columns = {'Meeting ID':'Name', 'Topic':'Email', 'User Email':'Duration (Minutes)'}, inplace = True)
# Out:
# /Users/jacobyang/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
workshopReduced = workshop.drop([0,1]).reset_index().get(['Email', 'Duration (Minutes)'])
workshopReduced
# Out:
#                Email Duration (Minutes)
# 0     l5wei@ucsd.edu                  1
# 1     l5wei@ucsd.edu                  1
# 2     l5wei@ucsd.edu                 13
# 3    dbirla@ucsd.edu                  5
# 4    dbirla@ucsd.edu                  2
# ..               ...                ...
# 340  dbirla@ucsd.edu                  1
# 341  dbirla@ucsd.edu                 85
# 342  v5tran@ucsd.edu                 21
# 343   l5wei@ucsd.edu                  1
# 344   l5wei@ucsd.edu                  1
#
# [345 rows x 2 columns]

# %%
workshopReduced['Duration (Minutes)'] = workshopReduced['Duration (Minutes)'].astype(int)

# %%
workshopReduced = workshopReduced.groupby(by=['Email']).sum()
workshopReduced
# Out:
#                        Duration (Minutes)
# Email
# a5ortiz@ucsd.edu                       97
# admody@ucsd.edu                        66
# ajahmad@ucsd.edu                      109
# alausch@ucsd.edu                      134
# angandhi@ucsd.edu                      93
# ateittinen@ucsd.edu                   132
# btam@ucsd.edu                         115
# cehuey@ucsd.edu                       126
# cic002@ucsd.edu                       131
# cpullan@ucsd.edu                      137
# cxxie@ucsd.edu                        111
# danup@ucsd.edu                        102
# dbirla@ucsd.edu                       164
# dnt001@ucsd.edu                        17
# ebalci@ucsd.edu                        94
# gbabalayan@ucsd.edu                   150
# hinemoto@ucsd.edu                      98
# iaprelev@ucsd.edu                      98
# jcasasola@ucsd.edu                    132
# jel024@ucsd.edu                       100
# jilan@ucsd.edu                         88
# jpyang@ucsd.edu                        98
# jutang@ucsd.edu                        94
# jzhen@ucsd.edu                        108
# kctam@ucsd.edu                        101
# keyu@ucsd.edu                         111
# kgjan@ucsd.edu                        143
# kgyu@ucsd.edu                         103
# kkhong@ucsd.edu                       135
# klluu@ucsd.edu                         22
# knijjar@ucsd.edu                       89
# krvu@ucsd.edu                          98
# l5wei@ucsd.edu                        179
# mgloh@ucsd.edu                         19
# mjannamaraju@ucsd.edu                 110
# mshad@ucsd.edu                        135
# mvaughan@ucsd.edu                     125
# ojusuf@ucsd.edu                       108
# p5tan@ucsd.edu                        152
# pzahira@ucsd.edu                      137
# q6yang@ucsd.edu                       110
# s2zhu@ucsd.edu                        148
# shw050@ucsd.edu                        98
# smchoi@ucsd.edu                       149
# tgorthi@ucsd.edu                       37
# tnanda@ucsd.edu                       109
# v5tran@ucsd.edu                       150
# x3qu@ucsd.edu                          94
# y9liao@ucsd.edu                       124
# yrzhang@ucsd.edu                      151

# %%
selectedColumn = workshopReduced['Duration (Minutes)']
workshopTimes = selectedColumn.copy()
workshopTimes
# Out:
# Email
# a5ortiz@ucsd.edu          97
# admody@ucsd.edu           66
# ajahmad@ucsd.edu         109
# alausch@ucsd.edu         134
# angandhi@ucsd.edu         93
# ateittinen@ucsd.edu      132
# btam@ucsd.edu            115
# cehuey@ucsd.edu          126
# cic002@ucsd.edu          131
# cpullan@ucsd.edu         137
# cxxie@ucsd.edu           111
# danup@ucsd.edu           102
# dbirla@ucsd.edu          164
# dnt001@ucsd.edu           17
# ebalci@ucsd.edu           94
# gbabalayan@ucsd.edu      150
# hinemoto@ucsd.edu         98
# iaprelev@ucsd.edu         98
# jcasasola@ucsd.edu       132
# jel024@ucsd.edu          100
# jilan@ucsd.edu            88
# jpyang@ucsd.edu           98
# jutang@ucsd.edu           94
# jzhen@ucsd.edu           108
# kctam@ucsd.edu           101
# keyu@ucsd.edu            111
# kgjan@ucsd.edu           143
# kgyu@ucsd.edu            103
# kkhong@ucsd.edu          135
# klluu@ucsd.edu            22
# knijjar@ucsd.edu          89
# krvu@ucsd.edu             98
# l5wei@ucsd.edu           179
# mgloh@ucsd.edu            19
# mjannamaraju@ucsd.edu    110
# mshad@ucsd.edu           135
# mvaughan@ucsd.edu        125
# ojusuf@ucsd.edu          108
# p5tan@ucsd.edu           152
# pzahira@ucsd.edu         137
# q6yang@ucsd.edu          110
# s2zhu@ucsd.edu           148
# shw050@ucsd.edu           98
# smchoi@ucsd.edu          149
# tgorthi@ucsd.edu          37
# tnanda@ucsd.edu          109
# v5tran@ucsd.edu          150
# x3qu@ucsd.edu             94
# y9liao@ucsd.edu          124
# yrzhang@ucsd.edu         151
# Name: Duration (Minutes), dtype: int64

# %%
ax = workshopTimes.plot.hist(x = 'Duration (Minutes)', bins=20, ec = 'w', alpha=0.8)
